# %% [markdown]
# Задача 1

# %%
import numpy as np
X = np.array([[4,3,18],[22,11,2],[0,13,3]])
for i in X:
  for j in i:
    print("{:3}".format(j),end="")
  print()
# Out:
#   4  3 18
#  22 11  2
#   0 13  3

# %% [markdown]
# Задача 2

# %%
import numpy as np
X = np.random.uniform( size = (6,3))
for i in X:
  for j in i:
    print("{:22}".format(j),end="")
  print()
# Out:
#    0.35423505920464127    0.9732682902954752    0.6284005322922902
#    0.18982280087262904    0.6534666769370424    0.8467649302042211
#     0.9395022739871797    0.5970125842522878   0.12576072224880352
#     0.8386390145572297    0.2906599750158796     0.941460396000367
#     0.4521043248571631   0.38962070134417015    0.1440804515055324
#     0.9978801307679623    0.3712805850097408    0.7001767406516161

# %% [markdown]
# Задача 3

# %%
from google.colab import files
import csv
import pandas
import numpy as np
uploaded = files.upload()
data = pandas.read_csv('proceeds21.csv',index_col='Month')
x_test = data[['Department1','Department2','Department3','Department4']].values
r1 = np.sum(x_test, axis=1)
r2 = np.sum(x_test, axis=0)
mean = np.mean (x_test, axis = 0)
Answer1 = data.index.values[np.nonzero(r1>400)]
#месяцы, в которые суммарная выручка по отделам превысила 400
for i in Answer1:
  print("{:10}".format(i), end ="")
print()

Answer2 = data.columns.values[mean==mean.max()]
#отделы с максимальной средней выручкой за год
for i in Answer2:
  print("{:10}".format(i))

r3 = np.std(x_test, axis =0)
Answer3 = data.columns.values[np.nonzero(r3 == r3.max())]

#отделы с максимальной величиной стандартного отклонения прибыли
for i in Answer3:
  print("{:10}".format(i))
# Out:
#      <input type="file" id="files-c6e90b7f-914a-4234-bb56-67d7606d288c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c6e90b7f-914a-4234-bb56-67d7606d288c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
